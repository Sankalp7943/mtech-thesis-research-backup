# %%
#CNN on MNIST by Sankalp Sharma

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
tf.__version__
# Out:
# '2.3.1'

# %%
#import datasets

mnist= tf.keras.datasets.mnist #28x28 images
(x_train,y_train),(x_test,y_test)=mnist.load_data()
#print(x_train[0])
plt.imshow(x_train[0])

# %%
#normalizing the pixel values

x_train=tf.keras.utils.normalize(x_train,axis=1)
x_test=tf.keras.utils.normalize(x_test,axis=1)
plt.imshow(x_train[0])

# %%
#ADAM

# %%
#creating DL model
model=tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())#numpy could be used to flatten the 2d array
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))#neurons,activation func(rectified linear)
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))#output layer (neurons=no of classes,softmax layer for probability distribution)

# %%
#choosing optimizer,loss and output metrics
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
#model train with given epochs
original_hist=model.fit(x_train,y_train, epochs=20,batch_size=512,validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 118/118 [==============================] - 1s 7ms/step - loss: 0.6813 - accuracy: 0.8299 - val_loss: 0.2963 - val_accuracy: 0.9159
# Epoch 2/20
# 118/118 [==============================] - 1s 6ms/step - loss: 0.2506 - accuracy: 0.9271 - val_loss: 0.2118 - val_accuracy: 0.9386
# Epoch 3/20
# 118/118 [==============================] - 1s 6ms/step - loss: 0.1893 - accuracy: 0.9444 - val_loss: 0.1815 - val_accuracy: 0.9448
# Epoch 4/20
# 118/118 [==============================] - 1s 6ms/step - loss: 0.1515 - accuracy: 0.9558 - val_loss: 0.1525 - val_accuracy: 0.9540
# Epoch 5/20
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1250 - accuracy: 0.9636 - val_loss: 0.1362 - val_accuracy: 0.9594
# Epoch 6/20
# 118/118 [==============================] - 1s 6ms/step - loss: 0.1047 - accuracy: 0.9690 - val_loss: 0.1180 - val_accuracy: 0.9647
# Epoch 7/20
# ...

# %%
epochs = range(1, 21)
original_val_loss = original_hist.history['val_loss']

plt.plot(epochs, original_val_loss, 'bo', label='adam')
plt.xlabel('Epochs')
plt.ylim(0, 1)
plt.ylabel('Validation loss')
plt.legend()
plt.show()

# %%
#model testing on test data
val_loss,val_accuracy=model.evaluate(x_test,y_test)
print(val_loss,val_accuracy)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0997 - accuracy: 0.9719
# 0.0996999517083168 0.9718999862670898

# %%
# SGD OPTIMIZER

# %%
#creating DL model
model1=tf.keras.models.Sequential()
model1.add(tf.keras.layers.Flatten())#numpy could be used to flatten the 2d array
model1.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))#neurons,activation func(rectified linear)
model1.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model1.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))#output layer (neurons=no of classes,softmax layer for probability distribution)

# %%
#choosing optimizer,loss and output metrics
model1.compile(optimizer='SGD',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
#model train with given epochs
original_hist1=model1.fit(x_train,y_train, epochs=20,batch_size=512,validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 118/118 [==============================] - 1s 6ms/step - loss: 2.2624 - accuracy: 0.1968 - val_loss: 2.2082 - val_accuracy: 0.3518
# Epoch 2/20
# 118/118 [==============================] - 1s 5ms/step - loss: 2.1490 - accuracy: 0.4660 - val_loss: 2.0731 - val_accuracy: 0.5851
# Epoch 3/20
# 118/118 [==============================] - 1s 6ms/step - loss: 1.9822 - accuracy: 0.6324 - val_loss: 1.8653 - val_accuracy: 0.6971
# Epoch 4/20
# 118/118 [==============================] - 1s 6ms/step - loss: 1.7390 - accuracy: 0.7033 - val_loss: 1.5859 - val_accuracy: 0.7266
# Epoch 5/20
# 118/118 [==============================] - 1s 6ms/step - loss: 1.4493 - accuracy: 0.7308 - val_loss: 1.2939 - val_accuracy: 0.7556
# Epoch 6/20
# 118/118 [==============================] - 1s 6ms/step - loss: 1.1826 - accuracy: 0.7586 - val_loss: 1.0565 - val_accuracy: 0.7819
# Epoch 7/20
# ...

# %%
epochs = range(1, 21)
original_val_loss1 = original_hist1.history['val_loss']


plt.plot(epochs, original_val_loss1, 'bo', label='SGD')

plt.xlabel('Epochs')
plt.ylim(0, 10)
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#model testing on test data
val_loss1,val_accuracy1=model1.evaluate(x_test,y_test)
print(val_loss1,val_accuracy1)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.4001 - accuracy: 0.8919
# 0.40010401606559753 0.8919000029563904

# %%
#AdaDelta

# %%
#creating DL model
model4=tf.keras.models.Sequential()
model4.add(tf.keras.layers.Flatten())#numpy could be used to flatten the 2d array
model4.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))#neurons,activation func(rectified linear)
model4.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model4.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))#output layer (neurons=no of classes,softmax layer for probability distribution)

# %%
#choosing optimizer,loss and output metrics
model4.compile(optimizer='Adadelta',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
#model train with given epochs
original_hist4=model4.fit(x_train,y_train, epochs=20,batch_size=512,validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 118/118 [==============================] - 1s 7ms/step - loss: 2.3085 - accuracy: 0.0725 - val_loss: 2.3071 - val_accuracy: 0.0732
# Epoch 2/20
# 118/118 [==============================] - 1s 5ms/step - loss: 2.3018 - accuracy: 0.0780 - val_loss: 2.3002 - val_accuracy: 0.0794
# Epoch 3/20
# 118/118 [==============================] - 1s 6ms/step - loss: 2.2949 - accuracy: 0.0845 - val_loss: 2.2930 - val_accuracy: 0.0865
# Epoch 4/20
# 118/118 [==============================] - 1s 6ms/step - loss: 2.2877 - accuracy: 0.0909 - val_loss: 2.2857 - val_accuracy: 0.0927
# Epoch 5/20
# 118/118 [==============================] - 1s 7ms/step - loss: 2.2804 - accuracy: 0.0978 - val_loss: 2.2781 - val_accuracy: 0.1006
# Epoch 6/20
# 118/118 [==============================] - 1s 6ms/step - loss: 2.2729 - accuracy: 0.1052 - val_loss: 2.2705 - val_accuracy: 0.1095
# Epoch 7/20
# ...

# %%
epochs = range(1, 21)
original_val_loss4 = original_hist4.history['val_loss']


plt.plot(epochs, original_val_loss4, 'bo', label='Adadelta')

plt.xlabel('Epochs')
plt.ylim(0, 10)
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#model testing on test data
val_loss4,val_accuracy4=model.evaluate(x_test,y_test)
print(val_loss4,val_accuracy4)
# Out:
# 313/313 [==============================] - 0s 961us/step - loss: 0.0997 - accuracy: 0.9719
# 0.0996999517083168 0.9718999862670898

# %%
#Adagrad

# %%
#creating DL model
model5=tf.keras.models.Sequential()
model5.add(tf.keras.layers.Flatten())#numpy could be used to flatten the 2d array
model5.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))#neurons,activation func(rectified linear)
model5.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model5.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))#output layer (neurons=no of classes,softmax layer for probability distribution)

# %%
#choosing optimizer,loss and output metrics
model5.compile(optimizer='Adagrad',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
#model train with given epochs
original_hist5=model5.fit(x_train,y_train, epochs=20,batch_size=512,validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 118/118 [==============================] - 1s 6ms/step - loss: 2.3019 - accuracy: 0.1023 - val_loss: 2.2872 - val_accuracy: 0.1204
# Epoch 2/20
# 118/118 [==============================] - 1s 5ms/step - loss: 2.2748 - accuracy: 0.1394 - val_loss: 2.2604 - val_accuracy: 0.1729
# Epoch 3/20
# 118/118 [==============================] - 1s 5ms/step - loss: 2.2476 - accuracy: 0.1999 - val_loss: 2.2321 - val_accuracy: 0.2390
# Epoch 4/20
# 118/118 [==============================] - 1s 5ms/step - loss: 2.2181 - accuracy: 0.2728 - val_loss: 2.2007 - val_accuracy: 0.3172
# Epoch 5/20
# 118/118 [==============================] - 1s 5ms/step - loss: 2.1850 - accuracy: 0.3557 - val_loss: 2.1651 - val_accuracy: 0.4044
# Epoch 6/20
# 118/118 [==============================] - 1s 5ms/step - loss: 2.1475 - accuracy: 0.4355 - val_loss: 2.1250 - val_accuracy: 0.4763
# Epoch 7/20
# ...

# %%
epochs = range(1, 21)
original_val_loss5 = original_hist5.history['val_loss']


plt.plot(epochs, original_val_loss5, 'bo', label='Adagrad')

plt.xlabel('Epochs')
plt.ylim(0, 10)
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#model testing on test data
val_loss5,val_accuracy5=model.evaluate(x_test,y_test)
print(val_loss1,val_accuracy1)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0997 - accuracy: 0.9719
# 0.40010401606559753 0.8919000029563904

# %%
#NADAM

# %%
#creating DL model
model6=tf.keras.models.Sequential()
model6.add(tf.keras.layers.Flatten())#numpy could be used to flatten the 2d array
model6.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))#neurons,activation func(rectified linear)
model6.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model6.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))#output layer (neurons=no of classes,softmax layer for probability distribution)

# %%
#choosing optimizer,loss and output metrics
model6.compile(optimizer='Nadam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
#model train with given epochs
original_hist6=model6.fit(x_train,y_train, epochs=20,batch_size=512,validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 118/118 [==============================] - 1s 7ms/step - loss: 0.6486 - accuracy: 0.8307 - val_loss: 0.2982 - val_accuracy: 0.9146
# Epoch 2/20
# 118/118 [==============================] - 1s 5ms/step - loss: 0.2407 - accuracy: 0.9306 - val_loss: 0.2507 - val_accuracy: 0.9237
# Epoch 3/20
# 118/118 [==============================] - 1s 6ms/step - loss: 0.1815 - accuracy: 0.9468 - val_loss: 0.1776 - val_accuracy: 0.9482
# Epoch 4/20
# 118/118 [==============================] - 1s 6ms/step - loss: 0.1436 - accuracy: 0.9576 - val_loss: 0.1582 - val_accuracy: 0.9539
# Epoch 5/20
# 118/118 [==============================] - 1s 6ms/step - loss: 0.1173 - accuracy: 0.9654 - val_loss: 0.1301 - val_accuracy: 0.9625
# Epoch 6/20
# 118/118 [==============================] - 1s 6ms/step - loss: 0.0974 - accuracy: 0.9714 - val_loss: 0.1168 - val_accuracy: 0.9636
# Epoch 7/20
# ...

# %%
epochs = range(1, 21)
original_val_loss6 = original_hist6.history['val_loss']

plt.plot(epochs, original_val_loss6, 'bo', label='Nadam')
plt.xlabel('Epochs')
plt.ylim(0, 1)
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#model testing on test data
val_loss6,val_accuracy6=model.evaluate(x_test,y_test)
print(val_loss6,val_accuracy6)
# Out:
# 313/313 [==============================] - 0s 917us/step - loss: 0.0997 - accuracy: 0.9719
# 0.0996999517083168 0.9718999862670898

# %%
#RMSProp

# %%
#creating DL model
model7=tf.keras.models.Sequential()
model7.add(tf.keras.layers.Flatten())#numpy could be used to flatten the 2d array
model7.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))#neurons,activation func(rectified linear)
model7.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model7.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))#output layer (neurons=no of classes,softmax layer for probability distribution)

# %%
#choosing optimizer,loss and output metrics
model7.compile(optimizer='RMSprop',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
#model train with given epochs
original_hist7=model7.fit(x_train,y_train, epochs=20,batch_size=512,validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 118/118 [==============================] - 1s 6ms/step - loss: 0.5502 - accuracy: 0.8571 - val_loss: 0.3513 - val_accuracy: 0.8935
# Epoch 2/20
# 118/118 [==============================] - 1s 6ms/step - loss: 0.2484 - accuracy: 0.9272 - val_loss: 0.2156 - val_accuracy: 0.9329
# Epoch 3/20
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1859 - accuracy: 0.9456 - val_loss: 0.1797 - val_accuracy: 0.9440
# Epoch 4/20
# 118/118 [==============================] - 1s 6ms/step - loss: 0.1454 - accuracy: 0.9570 - val_loss: 0.1690 - val_accuracy: 0.9483
# Epoch 5/20
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1182 - accuracy: 0.9650 - val_loss: 0.1747 - val_accuracy: 0.9448
# Epoch 6/20
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0986 - accuracy: 0.9701 - val_loss: 0.1241 - val_accuracy: 0.9632
# Epoch 7/20
# ...

# %%
epochs = range(1, 21)
original_val_loss7 = original_hist7.history['val_loss']


plt.plot(epochs, original_val_loss7, 'bo', label='rmsprop')

plt.xlabel('Epochs')
plt.ylim(0, 1)
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#model testing on test data
val_loss7,val_accuracy7=model.evaluate(x_test,y_test)
print(val_loss7,val_accuracy7)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0997 - accuracy: 0.9719
# 0.0996999517083168 0.9718999862670898

# %%
#AMSGrad------------------------not in tensorflow but i should add https://tensorlayer.readthedocs.io/en/latest/_modules/tensorlayer/optimizers/amsgrad.html

# %%
#Adamax

# %%
#creating DL model
model9=tf.keras.models.Sequential()
model9.add(tf.keras.layers.Flatten())#numpy could be used to flatten the 2d array
model9.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))#neurons,activation func(rectified linear)
model9.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model9.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))#output layer (neurons=no of classes,softmax layer for probability distribution)

# %%
#choosing optimizer,loss and output metrics
model9.compile(optimizer='Adamax',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
#model train with given epochs
original_hist9=model9.fit(x_train,y_train, epochs=20,batch_size=512,validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 118/118 [==============================] - 1s 6ms/step - loss: 0.8786 - accuracy: 0.7875 - val_loss: 0.3685 - val_accuracy: 0.9012
# Epoch 2/20
# 118/118 [==============================] - 1s 5ms/step - loss: 0.3311 - accuracy: 0.9052 - val_loss: 0.2852 - val_accuracy: 0.9196
# Epoch 3/20
# 118/118 [==============================] - 1s 5ms/step - loss: 0.2737 - accuracy: 0.9215 - val_loss: 0.2489 - val_accuracy: 0.9291
# Epoch 4/20
# 118/118 [==============================] - 1s 5ms/step - loss: 0.2391 - accuracy: 0.9311 - val_loss: 0.2223 - val_accuracy: 0.9349
# Epoch 5/20
# 118/118 [==============================] - 1s 5ms/step - loss: 0.2113 - accuracy: 0.9397 - val_loss: 0.2020 - val_accuracy: 0.9398
# Epoch 6/20
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1902 - accuracy: 0.9452 - val_loss: 0.1870 - val_accuracy: 0.9442
# Epoch 7/20
# ...

# %%
epochs = range(1, 21)
original_val_loss9 = original_hist9.history['val_loss']


plt.plot(epochs, original_val_loss9, 'bo', label='Adamax')

plt.xlabel('Epochs')
plt.ylim(0, 1)
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#model testing on test data
val_loss9,val_accuracy9=model.evaluate(x_test,y_test)
print(val_loss9,val_accuracy9)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0997 - accuracy: 0.9719
# 0.0996999517083168 0.9718999862670898

# %%
#Ftrl

# %%
#creating DL model
model0=tf.keras.models.Sequential()
model0.add(tf.keras.layers.Flatten())#numpy could be used to flatten the 2d array
model0.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))#neurons,activation func(rectified linear)
model0.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model0.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))#output layer (neurons=no of classes,softmax layer for probability distribution)

# %%
#choosing optimizer,loss and output metrics
model0.compile(optimizer='Ftrl',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
#model train with given epochs
original_hist0=model0.fit(x_train,y_train, epochs=20,batch_size=512,validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 118/118 [==============================] - 1s 7ms/step - loss: 2.3025 - accuracy: 0.1124 - val_loss: 2.3025 - val_accuracy: 0.1135
# Epoch 2/20
# 118/118 [==============================] - 1s 6ms/step - loss: 2.3024 - accuracy: 0.1124 - val_loss: 2.3024 - val_accuracy: 0.1135
# Epoch 3/20
# 118/118 [==============================] - 1s 5ms/step - loss: 2.3024 - accuracy: 0.1124 - val_loss: 2.3023 - val_accuracy: 0.1135
# Epoch 4/20
# 118/118 [==============================] - 1s 5ms/step - loss: 2.3023 - accuracy: 0.1124 - val_loss: 2.3023 - val_accuracy: 0.1135
# Epoch 5/20
# 118/118 [==============================] - 1s 5ms/step - loss: 2.3023 - accuracy: 0.1124 - val_loss: 2.3022 - val_accuracy: 0.1135
# Epoch 6/20
# 118/118 [==============================] - 1s 5ms/step - loss: 2.3022 - accuracy: 0.1124 - val_loss: 2.3022 - val_accuracy: 0.1135
# Epoch 7/20
# ...

# %%
epochs = range(1, 21)
original_val_loss0 = original_hist0.history['val_loss']


plt.plot(epochs, original_val_loss0, 'bo', label='Ftrl')

plt.xlabel('Epochs')
plt.ylim(0, 10)
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#model testing on test data
val_loss0,val_accuracy0=model.evaluate(x_test,y_test)
print(val_loss0,val_accuracy0)
# Out:
# 313/313 [==============================] - 0s 939us/step - loss: 0.0997 - accuracy: 0.9719
# 0.0996999517083168 0.9718999862670898

# %%
epochs = range(1, 21)

plt.plot(epochs, original_val_loss,'bo', label='Ftrl')

plt.xlabel('Epochs')
plt.ylim(0, 5)
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#batch size 1000

# %%
epochs = range(1, 21)
original_val_loss = original_hist.history['val_loss']
original_val_loss1 = original_hist1.history['val_loss']
original_val_loss4 = original_hist4.history['val_loss']
original_val_loss5 = original_hist5.history['val_loss']
original_val_loss6 = original_hist6.history['val_loss']
original_val_loss7 = original_hist7.history['val_loss']
original_val_loss9 = original_hist9.history['val_loss']
original_val_loss0 = original_hist0.history['val_loss']

plt.figure(figsize=(15,10))
plt.ylim(0,2.5)

plt.plot(epochs, original_val_loss, '--', label='adam')
plt.plot(epochs, original_val_loss1, '-.', label='SGD')
plt.plot(epochs, original_val_loss4, '--', label='Adadelta')
plt.plot(epochs, original_val_loss5, '--', label='Adagrad')
plt.plot(epochs, original_val_loss6, '-.', label='Nadam')
plt.plot(epochs, original_val_loss7, '--', label='rmsprop')
plt.plot(epochs, original_val_loss9, '-.', label='Adamax')
plt.plot(epochs, original_val_loss0, '--', label='Ftrl')

plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#batch size 10000

# %%
epochs = range(1, 21)
original_val_loss = original_hist.history['val_loss']
original_val_loss1 = original_hist1.history['val_loss']
original_val_loss4 = original_hist4.history['val_loss']
original_val_loss5 = original_hist5.history['val_loss']
original_val_loss6 = original_hist6.history['val_loss']
original_val_loss7 = original_hist7.history['val_loss']
original_val_loss9 = original_hist9.history['val_loss']
original_val_loss0 = original_hist0.history['val_loss']

plt.figure(figsize=(15,10))
plt.ylim(0,3)

plt.plot(epochs, original_val_loss, '--', label='adam')
plt.plot(epochs, original_val_loss1, '-.', label='SGD')
plt.plot(epochs, original_val_loss4, '--', label='Adadelta')
plt.plot(epochs, original_val_loss5, '--', label='Adagrad')
plt.plot(epochs, original_val_loss6, '-.', label='Nadam')
plt.plot(epochs, original_val_loss7, '--', label='rmsprop')
plt.plot(epochs, original_val_loss9, '-.', label='Adamax')
plt.plot(epochs, original_val_loss0, '--', label='Ftrl')

plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#batch size 100

# %%
epochs = range(1, 21)
original_val_loss = original_hist.history['val_loss']
original_val_loss1 = original_hist1.history['val_loss']
original_val_loss4 = original_hist4.history['val_loss']
original_val_loss5 = original_hist5.history['val_loss']
original_val_loss6 = original_hist6.history['val_loss']
original_val_loss7 = original_hist7.history['val_loss']
original_val_loss9 = original_hist9.history['val_loss']
original_val_loss0 = original_hist0.history['val_loss']

plt.figure(figsize=(15,10))
plt.ylim(0,2.5)

plt.plot(epochs, original_val_loss, '--', label='adam')
plt.plot(epochs, original_val_loss1, '-.', label='SGD')
plt.plot(epochs, original_val_loss4, '--', label='Adadelta')
plt.plot(epochs, original_val_loss5, '--', label='Adagrad')
plt.plot(epochs, original_val_loss6, '-.', label='Nadam')
plt.plot(epochs, original_val_loss7, '--', label='rmsprop')
plt.plot(epochs, original_val_loss9, '-.', label='Adamax')
plt.plot(epochs, original_val_loss0, '--', label='Ftrl')

plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#batch 512

# %%
epochs = range(1, 21)
original_val_loss = original_hist.history['val_loss']
original_val_loss1 = original_hist1.history['val_loss']
original_val_loss4 = original_hist4.history['val_loss']
original_val_loss5 = original_hist5.history['val_loss']
original_val_loss6 = original_hist6.history['val_loss']
original_val_loss7 = original_hist7.history['val_loss']
original_val_loss9 = original_hist9.history['val_loss']
original_val_loss0 = original_hist0.history['val_loss']

plt.figure(figsize=(15,10))
plt.ylim(0,2.5)

plt.plot(epochs, original_val_loss, '--', label='adam')
plt.plot(epochs, original_val_loss1, '-.', label='SGD')
plt.plot(epochs, original_val_loss4, '--', label='Adadelta')
plt.plot(epochs, original_val_loss5, '--', label='Adagrad')
plt.plot(epochs, original_val_loss6, '-.', label='Nadam')
plt.plot(epochs, original_val_loss7, '--', label='rmsprop')
plt.plot(epochs, original_val_loss9, '-.', label='Adamax')
plt.plot(epochs, original_val_loss0, '--', label='Ftrl')

plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#batch 4096

# %%
epochs = range(1, 21)
original_val_loss = original_hist.history['val_loss']
original_val_loss1 = original_hist1.history['val_loss']
original_val_loss4 = original_hist4.history['val_loss']
original_val_loss5 = original_hist5.history['val_loss']
original_val_loss6 = original_hist6.history['val_loss']
original_val_loss7 = original_hist7.history['val_loss']
original_val_loss9 = original_hist9.history['val_loss']
original_val_loss0 = original_hist0.history['val_loss']

plt.figure(figsize=(15,10))
plt.ylim(0,2.5)

plt.plot(epochs, original_val_loss, '--', label='adam')
plt.plot(epochs, original_val_loss1, '-.', label='SGD')
plt.plot(epochs, original_val_loss4, '--', label='Adadelta')
plt.plot(epochs, original_val_loss5, '--', label='Adagrad')
plt.plot(epochs, original_val_loss6, '-.', label='Nadam')
plt.plot(epochs, original_val_loss7, '--', label='rmsprop')
plt.plot(epochs, original_val_loss9, '-.', label='Adamax')
plt.plot(epochs, original_val_loss0, '--', label='Ftrl')

plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()
