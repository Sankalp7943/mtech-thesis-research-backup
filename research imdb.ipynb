# %%
from keras.datasets import imdb
import numpy as np
from keras import models
from keras import layers
import matplotlib.pyplot as plt
 
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
 
def vectorize_sequences(sequences, dimension=10000):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.  # set specific indices of results[i] to 1s
    return results
 
# Our vectorized training data
x_train = vectorize_sequences(train_data)
# Our vectorized test data
x_test = vectorize_sequences(test_data)
# Our vectorized labels
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
#rmsprop


original_model = models.Sequential()
original_model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
original_model.add(layers.Dense(16, activation='relu'))
original_model.add(layers.Dense(1, activation='sigmoid'))

original_model.compile(optimizer='rmsprop',
                       loss='binary_crossentropy',
                       metrics=['acc'])
original_hist = original_model.fit(x_train, y_train,
                                   epochs=20,
                                   batch_size=512,
                                   validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 2s 36ms/step - loss: 0.4469 - acc: 0.8272 - val_acc: 0.8758 - val_loss: 0.3409
# Epoch 2/20
# 49/49 [==============================] - 1s 20ms/step - loss: 0.2604 - acc: 0.9085 - val_acc: 0.8846 - val_loss: 0.2911
# Epoch 3/20
# 49/49 [==============================] - 1s 19ms/step - loss: 0.2004 - acc: 0.9288 - val_acc: 0.8875 - val_loss: 0.2805
# Epoch 4/20
# 49/49 [==============================] - 1s 19ms/step - loss: 0.1673 - acc: 0.9402 - val_acc: 0.8794 - val_loss: 0.3046
# Epoch 5/20
# 49/49 [==============================] - 1s 18ms/step - loss: 0.1468 - acc: 0.9472 - val_acc: 0.8807 - val_loss: 0.3074
# Epoch 6/20
# 49/49 [==============================] - 1s 18ms/step - loss: 0.1269 - acc: 0.9556 - val_acc: 0.8771 - val_loss: 0.3304
# Epoch 7/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.1128 - acc: 0.9613 - val_acc: 0.8738 - val_loss: 0.3539
# Epoch 8/20
# ...

# %%
#Adadelta


original_model1 = models.Sequential()
original_model1.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
original_model1.add(layers.Dense(16, activation='relu'))
original_model1.add(layers.Dense(1, activation='sigmoid'))

original_model1.compile(optimizer='Adadelta',
                       loss='binary_crossentropy',
                       metrics=['acc'])
original_hist1 = original_model1.fit(x_train, y_train,
                                   epochs=20,
                                   batch_size=512,
                                   validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 1s 28ms/step - loss: 0.7002 - acc: 0.5000 - val_acc: 0.5000 - val_loss: 0.6999
# Epoch 2/20
# 49/49 [==============================] - 1s 18ms/step - loss: 0.6995 - acc: 0.5000 - val_acc: 0.5000 - val_loss: 0.6993
# Epoch 3/20
# 49/49 [==============================] - 1s 18ms/step - loss: 0.6988 - acc: 0.5000 - val_acc: 0.5002 - val_loss: 0.6987
# Epoch 4/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.6982 - acc: 0.5000 - val_acc: 0.5002 - val_loss: 0.6981
# Epoch 5/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.6976 - acc: 0.5000 - val_acc: 0.5003 - val_loss: 0.6975
# Epoch 6/20
# 49/49 [==============================] - 1s 16ms/step - loss: 0.6971 - acc: 0.5001 - val_acc: 0.5004 - val_loss: 0.6970
# Epoch 7/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.6966 - acc: 0.5001 - val_acc: 0.5004 - val_loss: 0.6965
# Epoch 8/20
# ...

# %%
#adam


original_model2 = models.Sequential()
original_model2.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
original_model2.add(layers.Dense(16, activation='relu'))
original_model2.add(layers.Dense(1, activation='sigmoid'))

original_model2.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['acc'])
original_hist2 = original_model2.fit(x_train, y_train,
                                   epochs=20,
                                   batch_size=512,
                                   validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 1s 29ms/step - loss: 0.5011 - acc: 0.7944 - val_acc: 0.8754 - val_loss: 0.3389
# Epoch 2/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.2511 - acc: 0.9091 - val_acc: 0.8876 - val_loss: 0.2832
# Epoch 3/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.1790 - acc: 0.9383 - val_acc: 0.8857 - val_loss: 0.2885
# Epoch 4/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.1397 - acc: 0.9536 - val_acc: 0.8803 - val_loss: 0.3099
# Epoch 5/20
# 49/49 [==============================] - 1s 16ms/step - loss: 0.1100 - acc: 0.9658 - val_acc: 0.8735 - val_loss: 0.3399
# Epoch 6/20
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0858 - acc: 0.9756 - val_acc: 0.8701 - val_loss: 0.3737
# Epoch 7/20
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0667 - acc: 0.9828 - val_acc: 0.8660 - val_loss: 0.4139
# Epoch 8/20
# ...

# %%
#SGD


original_model3 = models.Sequential()
original_model3.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
original_model3.add(layers.Dense(16, activation='relu'))
original_model3.add(layers.Dense(1, activation='sigmoid'))

original_model3.compile(optimizer='SGD',
                       loss='binary_crossentropy',
                       metrics=['acc'])
original_hist3 = original_model3.fit(x_train, y_train,
                                   epochs=20,
                                   batch_size=512,
                                   validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 1s 26ms/step - loss: 0.6951 - acc: 0.4847 - val_acc: 0.5007 - val_loss: 0.6932
# Epoch 2/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.6923 - acc: 0.5167 - val_acc: 0.5354 - val_loss: 0.6914
# Epoch 3/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.6900 - acc: 0.5550 - val_acc: 0.5758 - val_loss: 0.6886
# Epoch 4/20
# 49/49 [==============================] - 1s 16ms/step - loss: 0.6861 - acc: 0.5957 - val_acc: 0.6193 - val_loss: 0.6836
# Epoch 5/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.6794 - acc: 0.6398 - val_acc: 0.6612 - val_loss: 0.6757
# Epoch 6/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.6700 - acc: 0.6772 - val_acc: 0.7004 - val_loss: 0.6654
# Epoch 7/20
# 49/49 [==============================] - 1s 18ms/step - loss: 0.6582 - acc: 0.7160 - val_acc: 0.7324 - val_loss: 0.6528
# Epoch 8/20
# ...

# %%
#Nadam


original_model4 = models.Sequential()
original_model4.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
original_model4.add(layers.Dense(16, activation='relu'))
original_model4.add(layers.Dense(1, activation='sigmoid'))

original_model4.compile(optimizer='Nadam',
                       loss='binary_crossentropy',
                       metrics=['acc'])
original_hist4 = original_model4.fit(x_train, y_train,
                                   epochs=20,
                                   batch_size=512,
                                   validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 1s 29ms/step - loss: 0.4673 - acc: 0.8021 - val_acc: 0.8800 - val_loss: 0.3285
# Epoch 2/20
# 49/49 [==============================] - 1s 19ms/step - loss: 0.2409 - acc: 0.9145 - val_acc: 0.8775 - val_loss: 0.3055
# Epoch 3/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.1765 - acc: 0.9376 - val_acc: 0.8826 - val_loss: 0.2951
# Epoch 4/20
# 49/49 [==============================] - 1s 19ms/step - loss: 0.1436 - acc: 0.9519 - val_acc: 0.8754 - val_loss: 0.3220
# Epoch 5/20
# 49/49 [==============================] - 1s 18ms/step - loss: 0.1180 - acc: 0.9609 - val_acc: 0.8721 - val_loss: 0.3470
# Epoch 6/20
# 49/49 [==============================] - 1s 18ms/step - loss: 0.1011 - acc: 0.9678 - val_acc: 0.8703 - val_loss: 0.3763
# Epoch 7/20
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0836 - acc: 0.9735 - val_acc: 0.8656 - val_loss: 0.4149
# Epoch 8/20
# ...

# %%
#Adagrad


original_model5 = models.Sequential()
original_model5.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
original_model5.add(layers.Dense(16, activation='relu'))
original_model5.add(layers.Dense(1, activation='sigmoid'))

original_model5.compile(optimizer='Adagrad',
                       loss='binary_crossentropy',
                       metrics=['acc'])
original_hist5 = original_model5.fit(x_train, y_train,
                                   epochs=20,
                                   batch_size=512,
                                   validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 1s 29ms/step - loss: 0.6922 - acc: 0.5201 - val_acc: 0.5309 - val_loss: 0.6913
# Epoch 2/20
# 49/49 [==============================] - 1s 18ms/step - loss: 0.6909 - acc: 0.5343 - val_acc: 0.5450 - val_loss: 0.6900
# Epoch 3/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.6895 - acc: 0.5486 - val_acc: 0.5603 - val_loss: 0.6886
# Epoch 4/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.6879 - acc: 0.5653 - val_acc: 0.5739 - val_loss: 0.6870
# Epoch 5/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.6860 - acc: 0.5816 - val_acc: 0.5901 - val_loss: 0.6850
# Epoch 6/20
# 49/49 [==============================] - 1s 18ms/step - loss: 0.6838 - acc: 0.5980 - val_acc: 0.6097 - val_loss: 0.6826
# Epoch 7/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.6810 - acc: 0.6190 - val_acc: 0.6289 - val_loss: 0.6797
# Epoch 8/20
# ...

# %%
#Adamax


original_model6 = models.Sequential()
original_model6.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
original_model6.add(layers.Dense(16, activation='relu'))
original_model6.add(layers.Dense(1, activation='sigmoid'))

original_model6.compile(optimizer='Adamax',
                       loss='binary_crossentropy',
                       metrics=['acc'])
original_hist6 = original_model6.fit(x_train, y_train,
                                   epochs=20,
                                   batch_size=512,
                                   validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 1s 30ms/step - loss: 0.5378 - acc: 0.7910 - val_acc: 0.8553 - val_loss: 0.4144
# Epoch 2/20
# 49/49 [==============================] - 3s 52ms/step - loss: 0.3253 - acc: 0.8884 - val_acc: 0.8807 - val_loss: 0.3152
# Epoch 3/20
# 49/49 [==============================] - 1s 18ms/step - loss: 0.2453 - acc: 0.9134 - val_acc: 0.8885 - val_loss: 0.2868
# Epoch 4/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.2065 - acc: 0.9283 - val_acc: 0.8884 - val_loss: 0.2791
# Epoch 5/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.1815 - acc: 0.9374 - val_acc: 0.8875 - val_loss: 0.2802
# Epoch 6/20
# 49/49 [==============================] - 1s 18ms/step - loss: 0.1634 - acc: 0.9452 - val_acc: 0.8860 - val_loss: 0.2867
# Epoch 7/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.1480 - acc: 0.9505 - val_acc: 0.8849 - val_loss: 0.2928
# Epoch 8/20
# ...

# %%
#Ftrl


original_model7 = models.Sequential()
original_model7.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
original_model7.add(layers.Dense(16, activation='relu'))
original_model7.add(layers.Dense(1, activation='sigmoid'))

original_model7.compile(optimizer='Ftrl',
                       loss='binary_crossentropy',
                       metrics=['acc'])
original_hist7 = original_model7.fit(x_train, y_train,
                                   epochs=20,
                                   batch_size=512,
                                   validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 2s 44ms/step - loss: 0.6932 - acc: 0.4996 - val_acc: 0.5000 - val_loss: 0.6931
# Epoch 2/20
# 49/49 [==============================] - 1s 21ms/step - loss: 0.6931 - acc: 0.4958 - val_acc: 0.5000 - val_loss: 0.6931
# Epoch 3/20
# 49/49 [==============================] - 1s 19ms/step - loss: 0.6931 - acc: 0.4950 - val_acc: 0.5000 - val_loss: 0.6931
# Epoch 4/20
# 49/49 [==============================] - 1s 19ms/step - loss: 0.6931 - acc: 0.4954 - val_acc: 0.5000 - val_loss: 0.6931
# Epoch 5/20
# 49/49 [==============================] - 1s 18ms/step - loss: 0.6931 - acc: 0.4989 - val_acc: 0.5000 - val_loss: 0.6931
# Epoch 6/20
# 49/49 [==============================] - 1s 18ms/step - loss: 0.6931 - acc: 0.4942 - val_acc: 0.5000 - val_loss: 0.6931
# Epoch 7/20
# 49/49 [==============================] - 1s 19ms/step - loss: 0.6931 - acc: 0.4993 - val_acc: 0.5000 - val_loss: 0.6931
# Epoch 8/20
# ...

# %%
#batch size 1000

# %%
epochs = range(1, 21)
original_val_loss = original_hist.history['val_loss']
original_val_loss1 = original_hist1.history['val_loss']
original_val_loss2 = original_hist2.history['val_loss']
original_val_loss3 = original_hist3.history['val_loss']
original_val_loss4 = original_hist4.history['val_loss']
original_val_loss5 = original_hist5.history['val_loss']
original_val_loss6 = original_hist6.history['val_loss']
original_val_loss7 = original_hist7.history['val_loss']

plt.figure(figsize=(15,10))
plt.ylim(0, 1)

plt.plot(epochs, original_val_loss, '-.', label='rmsprop')
plt.plot(epochs, original_val_loss1, '--', label='Adadelta')
plt.plot(epochs, original_val_loss2, '-.', label='Adam')
plt.plot(epochs, original_val_loss3, '-.', label='SGD')
plt.plot(epochs, original_val_loss4, '--', label='Nadam')
plt.plot(epochs, original_val_loss5, '-.', label='Adagrad')
plt.plot(epochs, original_val_loss6, '--', label='Adamax')
plt.plot(epochs, original_val_loss7, '-.', label='Ftrl')



plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#batch size 10000

# %%
epochs = range(1, 21)
original_val_loss = original_hist.history['val_loss']
original_val_loss1 = original_hist1.history['val_loss']
original_val_loss2 = original_hist2.history['val_loss']
original_val_loss3 = original_hist3.history['val_loss']
original_val_loss4 = original_hist4.history['val_loss']
original_val_loss5 = original_hist5.history['val_loss']
original_val_loss6 = original_hist6.history['val_loss']
original_val_loss7 = original_hist7.history['val_loss']

plt.figure(figsize=(15,10))
plt.ylim(0, 1)

plt.plot(epochs, original_val_loss, '-.', label='rmsprop')
plt.plot(epochs, original_val_loss1, '--', label='Adadelta')
plt.plot(epochs, original_val_loss2, '-.', label='Adam')
plt.plot(epochs, original_val_loss3, '-.', label='SGD')
plt.plot(epochs, original_val_loss4, '--', label='Nadam')
plt.plot(epochs, original_val_loss5, '-.', label='Adagrad')
plt.plot(epochs, original_val_loss6, '--', label='Adamax')
plt.plot(epochs, original_val_loss7, '-.', label='Ftrl')



plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#batch size =4096

# %%
epochs = range(1, 21)
original_val_loss = original_hist.history['val_loss']
original_val_loss1 = original_hist1.history['val_loss']
original_val_loss2 = original_hist2.history['val_loss']
original_val_loss3 = original_hist3.history['val_loss']
original_val_loss4 = original_hist4.history['val_loss']
original_val_loss5 = original_hist5.history['val_loss']
original_val_loss6 = original_hist6.history['val_loss']
original_val_loss7 = original_hist7.history['val_loss']

plt.figure(figsize=(15,10))
plt.ylim(0, 1)

plt.plot(epochs, original_val_loss, '-.', label='rmsprop')
plt.plot(epochs, original_val_loss1, '--', label='Adadelta')
plt.plot(epochs, original_val_loss2, '-.', label='Adam')
plt.plot(epochs, original_val_loss3, '-.', label='SGD')
plt.plot(epochs, original_val_loss4, '--', label='Nadam')
plt.plot(epochs, original_val_loss5, '-.', label='Adagrad')
plt.plot(epochs, original_val_loss6, '--', label='Adamax')
plt.plot(epochs, original_val_loss7, '-.', label='Ftrl')



plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#batch size 100

# %%
epochs = range(1, 21)
original_val_loss = original_hist.history['val_loss']
original_val_loss1 = original_hist1.history['val_loss']
original_val_loss2 = original_hist2.history['val_loss']
original_val_loss3 = original_hist3.history['val_loss']
original_val_loss4 = original_hist4.history['val_loss']
original_val_loss5 = original_hist5.history['val_loss']
original_val_loss6 = original_hist6.history['val_loss']
original_val_loss7 = original_hist7.history['val_loss']

plt.figure(figsize=(15,10))
plt.ylim(0, 2)

plt.plot(epochs, original_val_loss, '-.', label='rmsprop')
plt.plot(epochs, original_val_loss1, '--', label='Adadelta')
plt.plot(epochs, original_val_loss2, '-.', label='Adam')
plt.plot(epochs, original_val_loss3, '-.', label='SGD')
plt.plot(epochs, original_val_loss4, '--', label='Nadam')
plt.plot(epochs, original_val_loss5, '-.', label='Adagrad')
plt.plot(epochs, original_val_loss6, '--', label='Adamax')
plt.plot(epochs, original_val_loss7, '-.', label='Ftrl')



plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#batch size 512

# %%
epochs = range(1, 21)
original_val_loss = original_hist.history['val_loss']
original_val_loss1 = original_hist1.history['val_loss']
original_val_loss2 = original_hist2.history['val_loss']
original_val_loss3 = original_hist3.history['val_loss']
original_val_loss4 = original_hist4.history['val_loss']
original_val_loss5 = original_hist5.history['val_loss']
original_val_loss6 = original_hist6.history['val_loss']
original_val_loss7 = original_hist7.history['val_loss']

plt.figure(figsize=(15,10))
plt.ylim(0, 1)

plt.plot(epochs, original_val_loss, '-.', label='rmsprop')
plt.plot(epochs, original_val_loss1, '--', label='Adadelta')
plt.plot(epochs, original_val_loss2, '-.', label='Adam')
plt.plot(epochs, original_val_loss3, '-.', label='SGD')
plt.plot(epochs, original_val_loss4, '--', label='Nadam')
plt.plot(epochs, original_val_loss5, '-.', label='Adagrad')
plt.plot(epochs, original_val_loss6, '--', label='Adamax')
plt.plot(epochs, original_val_loss7, '-.', label='Ftrl')



plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
#ADADELTA AND FTRL ARE FAILING and overlapping

# %%
#install libraries
'''
tensorflow
tensorflow-gpu
keras
matplotlib
pandas
numpy
pip upgarde

'''
import numpy as np
import pandas as pd
import matplotlib as plt

'''
arguments such as batch size= error optmisers=[]/else all, xtrain_y-train epochs. activation functions and input shape
validation
'''

original_model7 = models.Sequential()
original_model7.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
original_model7.add(layers.Dense(16, activation='relu'))
original_model7.add(layers.Dense(1, activation='sigmoid'))


def func(x_train,y_train,model,validation,loss,epoch,batch):

    model.compile(optimizer='Ftrl',loss=loss,metrics=['acc'])
    hist7 = model.fit(x_train, y_train,epochs=epoch,batch_size=batch,validation_data=validation)

func(x_train,y_train,original_model7,(x_test,y_test),'binary_crossentropy',20,512)
# Out:
# Epoch 1/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.6932 - acc: 0.4954 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 2/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.6931 - acc: 0.4989 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 3/20
# 49/49 [==============================] - 1s 17ms/step - loss: 0.6931 - acc: 0.4986 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 4/20
# 49/49 [==============================] - 1s 16ms/step - loss: 0.6931 - acc: 0.4986 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 5/20
# 49/49 [==============================] - 1s 16ms/step - loss: 0.6931 - acc: 0.4985 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 6/20
# 49/49 [==============================] - 1s 16ms/step - loss: 0.6931 - acc: 0.4984 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 7/20
# 49/49 [==============================] - 1s 16ms/step - loss: 0.6931 - acc: 0.4968 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 8/20
# ...
